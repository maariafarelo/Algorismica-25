# %% [markdown]
# # Capítol 4 - Algorismes i Text

# %% [markdown]
# ### 4.1 Acronims

# %%
def acronim(frase):
    """
    Aquesta funció retorna l'acrònim d'una frase.
    
    Parameters
    ----------
    frase: string
    
    Returns
    -------
    acronim: string
    """
    # Separem la frase en paraules
    paraules = frase.split()
    # Agafem la primera lletra de cada paraula i la posem en majúscula
    acronim = ''.join([paraula[0].upper() for paraula in paraules if paraula])

    return acronim

# %%
assert acronim("Hola que tal") == 'HQT'
# Out:
# ['Hola', 'que', 'tal']
