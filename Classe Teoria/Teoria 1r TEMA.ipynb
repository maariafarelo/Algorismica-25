# %% [markdown]
# # **TEMA 1:**

# %% [markdown]
# ### --- DIA 1 (26-09-2025) ---

# %% [markdown]
# * Ha renovat la assignatura xd
# * Treballar amb Windows
# * Pycharm però farem servir jupiter notebook.

# %% [markdown]
# ![image.png](attachment:04d99db6-a7d0-493f-92c1-752823ba93a9.png)
